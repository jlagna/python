# %%
#### Null value treatment

# %%
import pandas as pd

import numpy as np

# %%
data = {
    "Product": ["Laptop", "Mobile", "Tablet", "Headphones", "TV", "Fridge"],
    "Price": [80000, 25000, np.nan, 2000, 45000, np.nan],
    "Quantity": [5, np.nan, 15, 8, 7, 3],
    "Discount": [10, np.nan, 5, 2, np.nan, 8]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
df
# Out:
# Original DataFrame:
#       Product    Price  Quantity  Discount
# 0      Laptop  80000.0       5.0      10.0
# 1      Mobile  25000.0       NaN       NaN
# 2      Tablet      NaN      15.0       5.0
# 3  Headphones   2000.0       8.0       2.0
# 4          TV  45000.0       7.0       NaN
# 5      Fridge      NaN       3.0       8.0

# %%
df.dropna(axis=0,how='all')
# Out:
#       Product    Price  Quantity  Discount
# 0      Laptop  80000.0       5.0      10.0
# 1      Mobile  25000.0       NaN       NaN
# 2      Tablet      NaN      15.0       5.0
# 3  Headphones   2000.0       8.0       2.0
# 4          TV  45000.0       7.0       NaN
# 5      Fridge      NaN       3.0       8.0

# %%
df.dropna(axis=0,how='any')
# Out:
#       Product    Price  Quantity  Discount
# 0      Laptop  80000.0       5.0      10.0
# 3  Headphones   2000.0       8.0       2.0

# %%
df.dropna(axis=1,how='all')
# Out:
#       Product    Price  Quantity  Discount
# 0      Laptop  80000.0       5.0      10.0
# 1      Mobile  25000.0       NaN       NaN
# 2      Tablet      NaN      15.0       5.0
# 3  Headphones   2000.0       8.0       2.0
# 4          TV  45000.0       7.0       NaN
# 5      Fridge      NaN       3.0       8.0

# %%
df.dropna(axis=1,how='any')
# Out:
#       Product
# 0      Laptop
# 1      Mobile
# 2      Tablet
# 3  Headphones
# 4          TV
# 5      Fridge

# %%
df.dropna(axis=0,how='all')
df.dropna(axis=0,how='any')
df.dropna(axis=1,how='all')
df.dropna(axis=1,how='any')
# Out:
#       Product
# 0      Laptop
# 1      Mobile
# 2      Tablet
# 3  Headphones
# 4          TV
# 5      Fridge

# %%
df
# Out:
#       Product    Price  Quantity  Discount
# 0      Laptop  80000.0       5.0      10.0
# 1      Mobile  25000.0       NaN       NaN
# 2      Tablet      NaN      15.0       5.0
# 3  Headphones   2000.0       8.0       2.0
# 4          TV  45000.0       7.0       NaN
# 5      Fridge      NaN       3.0       8.0

# %%
df = pd.DataFrame({
    "Customer": ["John", "Sara", np.nan, "Lily", "David", "Emma", "Chris", "Sophia"],
    "Age": [28, np.nan, np.nan, 40, np.nan, 30, 45, np.nan],
    "City": ["New York", "London", np.nan, "Sydney", "Paris", np.nan, "Berlin", "Tokyo"],
    "Purchase_Amount": [250, 400, np.nan, 150, 500, 600, np.nan, 350],
    "Feedback_Score": [5, np.nan, np.nan, 3, 5, np.nan, 2, 4]
})
df=pd.DataFrame(df)
df
df.dropna(axis=0,how='all')
df.dropna(axis=0,how='any')
df.dropna(axis=1,how='all')
df.dropna(axis=1,how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7]

# %%
df
# Out:
#   Customer   Age      City  Purchase_Amount  Feedback_Score
# 0     John  28.0  New York            250.0             5.0
# 1     Sara   NaN    London            400.0             NaN
# 2      NaN   NaN       NaN              NaN             NaN
# 3     Lily  40.0    Sydney            150.0             3.0
# 4    David   NaN     Paris            500.0             5.0
# 5     Emma  30.0       NaN            600.0             NaN
# 6    Chris  45.0    Berlin              NaN             2.0
# 7   Sophia   NaN     Tokyo            350.0             4.0

# %%
df.dropna(axis=1,how='any')
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4, 5, 6, 7]

# %%
df['Age'].fillna(20000,inplace=True)
# Out:
# /tmp/ipython-input-147727297.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(20000,inplace=True)

# %%
df
# Out:
#   Customer      Age      City  Purchase_Amount  Feedback_Score
# 0     John     28.0  New York            250.0             5.0
# 1     Sara  20000.0    London            400.0             NaN
# 2      NaN  20000.0       NaN              NaN             NaN
# 3     Lily     40.0    Sydney            150.0             3.0
# 4    David  20000.0     Paris            500.0             5.0
# 5     Emma     30.0       NaN            600.0             NaN
# 6    Chris     45.0    Berlin              NaN             2.0
# 7   Sophia  20000.0     Tokyo            350.0             4.0

# %%
df = pd.DataFrame({
    "Customer": ["John", "Sara", np.nan, "Lily", "David", "Emma", "Chris", "Sophia"],
    "Age": [28, np.nan, np.nan, 40, np.nan, 30, 45, np.nan],
    "City": ["New York", "London", np.nan, "Sydney", "Paris", np.nan, "Berlin", "Tokyo"],
    "Purchase_Amount": [250, 400, np.nan, 150, 500, 600, np.nan, 350],
    "Feedback_Score": [5, np.nan, np.nan, 3, 5, np.nan, 2, 4]
})
df=pd.DataFrame(df)
df['Age'].fillna(df['Age'].median(),inplace=True)
df
# Out:
# /tmp/ipython-input-3202573502.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(),inplace=True)
#   Customer   Age      City  Purchase_Amount  Feedback_Score
# 0     John  28.0  New York            250.0             5.0
# 1     Sara  35.0    London            400.0             NaN
# 2      NaN  35.0       NaN              NaN             NaN
# 3     Lily  40.0    Sydney            150.0             3.0
# 4    David  35.0     Paris            500.0             5.0
# 5     Emma  30.0       NaN            600.0             NaN
# 6    Chris  45.0    Berlin              NaN             2.0
# 7   Sophia  35.0     Tokyo            350.0             4.0

# %%
df['Age']
# Out:
# 0    28.0
# 1    35.0
# 2    35.0
# 3    40.0
# 4    35.0
# 5    30.0
# 6    45.0
# 7    35.0
# Name: Age, dtype: float64

# %%
df = pd.DataFrame({
    "Customer": ["John", "Sara", np.nan, "Lily", "David", "Emma", "Chris", "Sophia"],
    "Age": [28, np.nan, np.nan, 40, np.nan, 30, 45, np.nan],
    "City": ["New York", "London", np.nan, "Sydney", "Paris", np.nan, "Berlin", "Tokyo"],
    "Purchase_Amount": [250, 400, np.nan, 150, 500, 600, np.nan, 350],
    "Feedback_Score": [5, np.nan, np.nan, 3, 5, np.nan, 2, 4]
})
df=pd.DataFrame(df)

# %%
df['Age'].fillna(method='ffill')
# Out:
# /tmp/ipython-input-1265906299.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method='ffill')
# 0    28.0
# 1    28.0
# 2    28.0
# 3    40.0
# 4    40.0
# 5    30.0
# 6    45.0
# 7    45.0
# Name: Age, dtype: float64

# %%
df['Age'].fillna(method='bfill')
# Out:
# /tmp/ipython-input-3224957626.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df['Age'].fillna(method='bfill')
# 0    28.0
# 1    40.0
# 2    40.0
# 3    40.0
# 4    30.0
# 5    30.0
# 6    45.0
# 7     NaN
# Name: Age, dtype: float64

# %%
##### Null value treatment
  #### i will check null values
  ### Take percentage of null values
  ### confirm the threshold
  ### if it is beyond threshold drop the columns
  ### if it is less than threshold keep the columns
    #### if it is numercial : mean , medain
    #### if it is categorical : mode
    #### if it is data , time basesd : ffill or bfill

# %%
null_value_table=(df.isna().sum()/df.shape[0])*100

# %%
null_value_table[null_value_table>30].index

# %%
null_value_table[null_value_table<30].index

# %%
df.drop(['Age', 'Feedback_Score'],axis=1)

# %%
### Memory Optimization

# %%
import pandas as pd
df=pd.read_excel("/content/Sample - Superstore (2).xls")
df.head()

# %%
df.memory_usage().sum()/(1024*1024)

# %%
df['Row ID']=df['Row ID'].astype(np.int8)

# %%
df.memory_usage().sum()/(1024*1024)

# %%
df.columns

# %%
df.dtypes

# %%
np.iinfo(np.int8)

# %%
np.iinfo(np.int16),np.iinfo(np.int32)

# %%
df.select_dtypes(["int64"]).columns

# %%
 for col in df.select_dtypes(["int64"]).columns:
  col_type=df['col'].dtype
  c_min, c_max = df[col].min(), df[col].max()
        if str(col_type).startswith("int"):
            if c_min >= np.iinfo(np.int8).min and c_max <= np.iinfo(np.int8).max:
                df[col] = df[col].astype(np.int8)
            elif c_min >= np.iinfo(np.int16).min and c_max <= np.iinfo(np.int16).max:
                df[col] = df[col].astype(np.int16)
            elif c_min >= np.iinfo(np.int32).min and c_max <= np.iinfo(np.int32).max:
                df[col] = df[col].astype(np.int32)
            else:
                df[col] = df[col].astype(np.int64)
# Out:
#   File "/tmp/ipython-input-4080519419.py", line 4
#     if str(col_type).startswith("int"):
#     ^
# IndentationError: unexpected indent

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1396537375.py in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df[['Age','Feedback_Score']].fillna(20,inplace=)
