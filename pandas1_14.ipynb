# %%
#pandas is a fast,powerful,flexible and easy to use open source data
#analysis and manipulation tool
#pandas:panel datasets
#EDA:numbers,character data,visualizations

# %%
import pandas as pd

# %%
df=pd.DataFrame([[1,2,3],[4,5,6]],columns=['A',"B","c"],index='X Y'.split())
df
# Out:
#    A  B  c
# X  1  2  3
# Y  4  5  6

# %%
df=pd.DataFrame([[1,2,3],[4,5,6]],columns=['A',"B","c"],index='X Y'.split())
df
# Out:
#    A  B  c
# X  1  2  3
# Y  4  5  6

# %%
df.columns
# Out:
# Index(['A', 'B', 'c'], dtype='object')

# %%
df.index
# Out:
# Index(['X', 'Y'], dtype='object')

# %%
df.shape
# Out:
# (2, 3)

# %%
df.values
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
# 1. Dictionary of Lists
data1 = {
    "ID": [1, 2, 3],
    "Name": ["Aarav", "Priya", "Vikram"],
    "Score": [85, 90, 78]
}
df1 = pd.DataFrame(data1)
df1
# Out:
#    ID    Name  Score
# 0   1   Aarav     85
# 1   2   Priya     90
# 2   3  Vikram     78

# %%
# 4. List of Tuples
data4 = [
    (1, "Meera", 91),
    (2, "Sanjay", 84),
    (3, "Divya", 87)
]
df4 = pd.DataFrame(data4, columns=["ID", "Name", "Score"])
df4
# Out:
#    ID    Name  Score
# 0   1   Meera     91
# 1   2  Sanjay     84
# 2   3   Divya     87

# %%
data7 = {
    "ID": pd.Series([1, 2, 3]),
    "Name": pd.Series(["Suresh", "Neha", "Ajay"]),
    "Score": pd.Series([88, 79, 91])
}
df7 = pd.DataFrame(data7)
df7
# Out:
#    ID    Name  Score
# 0   1  Suresh     88
# 1   2    Neha     79
# 2   3    Ajay     91

# %%
import numpy as np
df=pd.DataFrame(np.random.randint(0,100,(5,5)),columns='p1 p2 p3 p4 p5'.split(),index='s1 s2 s3 s4 s5'.split())
df
# Out:
#     p1  p2  p3  p4  p5
# s1  30  32  12  86  36
# s2  62  15  15   5  10
# s3  26  88  33  23  35
# s4  84  68  73   0  30
# s5  96  31  72  47  94

# %%
import pandas as pd
df=pd.read_csv("/content/Sample - Superstore.xlsx",encoding="latin1")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-1657593656.py in <cell line: 0>()
#       1 import pandas as pd
# ----> 2 df=pd.read_csv("/content/Sample - Superstore.xlsx",encoding="latin1")
#       3 df.head()
#
# ...

# %%
df.shape
# Out:
# (5, 5)

# %%
df.columns
# Out:
# Index(['p1', 'p2', 'p3', 'p4', 'p5'], dtype='object')

# %%
df.index

# %%
df.iloc[0:2,0:2]
# Out:
#     p1  p2
# s1  30  32
# s2  62  15

# %%
df.columns
# Out:
# Index(['p1', 'p2', 'p3', 'p4', 'p5'], dtype='object')

# %%
df[['Order Date','Sales']].head(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-4120689465.py in <cell line: 0>()
# ----> 1 df[['Order Date','Sales']].head(2)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# ...

# %%
df.tail(2)
# Out:
#     p1  p2  p3  p4  p5
# s4  84  68  73   0  30
# s5  96  31  72  47  94

# %%
df.columns
# Out:
# Index(['p1', 'p2', 'p3', 'p4', 'p5'], dtype='object')

# %%
import pandas as pd

customers = pd.DataFrame({
    "CustomerID": [1, 2, 3, 3, 5],
    "Name": ["Aarav", "Priya", "Vikram", "Meera", "Sanjay"],
    "City": ["Delhi", "Mumbai", "Bangalore", "Chennai", "Hyderabad"]
})
print(customers)
# Out:
#    CustomerID    Name       City
# 0           1   Aarav      Delhi
# 1           2   Priya     Mumbai
# 2           3  Vikram  Bangalore
# 3           3   Meera    Chennai
# 4           5  Sanjay  Hyderabad

# %%
orders = pd.DataFrame({
    "OrderID": [101, 102, 103, 104, 105],
    "CustomerID": [3, 3, 5, 6, 7],
    "Product": ["Laptop", "Phone", "Tablet", "Camera", "Printer"]
})
orders
# Out:
#    OrderID  CustomerID  Product
# 0      101           3   Laptop
# 1      102           3    Phone
# 2      103           5   Tablet
# 3      104           6   Camera
# 4      105           7  Printer

# %%
customers
# Out:
#    CustomerID    Name       City
# 0           1   Aarav      Delhi
# 1           2   Priya     Mumbai
# 2           3  Vikram  Bangalore
# 3           3   Meera    Chennai
# 4           5  Sanjay  Hyderabad

# %%
customers
# Out:
#    CustomerID    Name       City
# 0           1   Aarav      Delhi
# 1           2   Priya     Mumbai
# 2           3  Vikram  Bangalore
# 3           3   Meera    Chennai
# 4           5  Sanjay  Hyderabad

# %%
inner = pd.merge(customers, orders, on="CustomerID", how="inner")
inner
# Out:
#    CustomerID    Name       City  OrderID Product
# 0           3  Vikram  Bangalore      101  Laptop
# 1           3  Vikram  Bangalore      102   Phone
# 2           3   Meera    Chennai      101  Laptop
# 3           3   Meera    Chennai      102   Phone
# 4           5  Sanjay  Hyderabad      103  Tablet
